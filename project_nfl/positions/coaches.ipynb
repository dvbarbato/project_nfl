# %%
import pandas as pd
import numpy as np
import requests, time
from bs4 import BeautifulSoup
import sqlalchemy

pd.set_option('display.max_columns', None)

# %%
name_table = 'coaches'

# %%
url = 'http://pfref.com/pi/share/mPeZI'

# %%
def read_html(url):
    pd.read_html(url)
   
    return pd.read_html(url)


def convert_df(lista):
    lista[0]
    
    return lista[0]


def rm_unnamed_col(dado):
    dt = dado.rename(columns={'Unnamed: 0_level_0':'',
                        'Unnamed: 1_level_0': '', 
                        'Unnamed: 2_level_0': '',
                        'Unnamed: 3_level_0': '',
                        'Unnamed: 4_level_0': '',
                        'Unnamed: 23_level_0': '',
                        'Unnamed: 17_level_0': ''
                             })
    return dt

# def add_col_characters(dataframe):
#     dataframe.loc[:,'All-Pro'] = dataframe['','Player'].str.contains('+', regex=False)
#     dataframe.loc[:,'Selected_Pro_Bowl'] = dataframe['','Player'].str.contains('*', regex=False)
   
#    return dataframe

# def clean_col_player(dataframe):
#     dataframe['','Player'] = dataframe['', 'Player'].str.replace('*','')
#     dataframe['','Player'] = dataframe['', 'Player'].str.replace('+','')
    
#     return dataframe

def limpar_todas_coluna(dataframe):
    dataframe.columns = [(c.lower().strip() + ' '+ d.lower().strip()).strip() for c,d in dataframe.columns]
    
    return dataframe.columns

# %%
def robo(url):
    lista = read_html(url)
    converter_em_dataframe = convert_df(lista)
    tirar_nomes_coluna= rm_unnamed_col(converter_em_dataframe)
    #adicionar_colunas_novas = add_col_characters(tirar_nomes_coluna)
    #limpar_coluna_player = clean_col_player(adicionar_colunas_novas)
    dataframe_final = limpar_todas_coluna(tirar_nomes_coluna)
    
    return tirar_nomes_coluna

# %%
robo(url)
# Out:
#                 coach   tm  2022 season g  2022 season w  2022 season l  \
# 0     Kliff Kingsbury  ARI             17              4             13
# 1        Arthur Smith  ATL             17              7             10
# 2       John Harbaugh  BAL             17             10              7
# 3      Sean McDermott  BUF             16             13              3
# 4         Steve Wilks  CAR             12              6              6
# 5          Matt Rhule  CAR              5              1              4
# 6       Matt Eberflus  CHI             17              3             14
# 7          Zac Taylor  CIN             16             12              4
# 8     Kevin Stefanski  CLE             17              7             10
# 9       Mike McCarthy  DAL             17             12              5
# 10  Nathaniel Hackett  DEN             15              4             11
# 11      Jerry Rosburg  DEN              2              1              1
# 12       Dan Campbell  DET             17              9              8
# 13       Matt LaFleur  GNB             17              8              9
# 14        Lovie Smith  HOU             17              3             13
# 15        Frank Reich  IND              9              3              5
# 16      Jeff Saturday  IND              8              1              7
# 17      Doug Pederson  JAX             17              9              8
# 18          Andy Reid  KAN             17             14              3
# 19     Brandon Staley  LAC             17             10              7
# 20         Sean McVay  LAR             17              5             12
# 21     Josh McDaniels  LVR             17              6             11
# 22      Mike McDaniel  MIA             17              9              8
# 23    Kevin O'Connell  MIN             17             13              4
# 24       Dennis Allen  NOR             17              7             10
# 25     Bill Belichick  NWE             17              8              9
# 26       Brian Daboll  NYG             17              9              7
# 27       Robert Saleh  NYJ             17              7             10
# 28      Nick Sirianni  PHI             17             14              3
# 29        Mike Tomlin  PIT             17              9              8
# 30       Pete Carroll  SEA             17              9              8
# 31      Kyle Shanahan  SFO             17             13              4
# 32        Todd Bowles  TAM             17              8              9
# 33        Mike Vrabel  TEN             17              7             10
# 34         Ron Rivera  WAS             17              8              8
#
#     2022 season t  w/ team g  w/ team w  w/ team l  w/ team t  career g  \
# 0               0         66         28         37          1        66
# 1               0         34         14         20          0        34
# 2               0        242        147         95          0       242
# 3               0         97         62         35          0        97
# 4               0         12          6          6          0        28
# 5               0         38         11         27          0        38
# 6               0         17          3         14          0        17
# 7               0         65         28         36          1        65
# 8               0         50         26         24          0        50
# 9               0         50         30         20          0       254
# 10              0         15          4         11          0        15
# 11              0          2          1          1          0         2
# 12              0         34         12         21          1        46
# 13              0         66         47         19          0        66
# 14              1         17          3         13          1       193
# 15              1         74         40         33          1        74
# 16              0          8          1          7          0         8
# 17              0         17          9          8          0        97
# 18              0        162        117         45          0       386
# 19              0         34         19         15          0        34
# 20              0         98         60         38          0        98
# 21              0         17          6         11          0        45
# 22              0         17          9          8          0        17
# 23              0         17         13          4          0        17
# 24              0         17          7         10          0        53
# 25              0        370        262        108          0       450
# 26              1         17          9          7          1        17
# 27              0         34         11         23          0        34
# 28              0         34         23         11          0        34
# 29              0        258        163         93          2       258
# 30              0        210        128         81          1       274
# 31              0         98         52         46          0        98
# 32              0         17          8          9          0        84
# 33              0         82         48         34          0        82
# 34              1         50         22         27          1       190
#
#     career w  career l  career t  playoffs g plyf  playoffs w plyf  \
# 0         28        37         1              NaN              NaN
# 1         14        20         0              NaN              NaN
# 2        147        95         0              1.0              0.0
# 3         62        35         0              2.0              1.0
# 4          9        19         0              NaN              NaN
# 5         11        27         0              NaN              NaN
# 6          3        14         0              NaN              NaN
# 7         28        36         1              3.0              2.0
# 8         26        24         0              NaN              NaN
# 9        155        97         2              2.0              1.0
# 10         4        11         0              NaN              NaN
# 11         1         1         0              NaN              NaN
# 12        17        28         1              NaN              NaN
# 13        47        19         0              NaN              NaN
# 14        92       100         1              NaN              NaN
# 15        40        33         1              NaN              NaN
# 16         1         7         0              NaN              NaN
# 17        51        45         1              2.0              1.0
# 18       247       138         1              2.0              2.0
# 19        19        15         0              1.0              0.0
# 20        60        38         0              NaN              NaN
# 21        17        28         0              NaN              NaN
# 22         9         8         0              1.0              0.0
# 23        13         4         0              1.0              0.0
# 24        15        38         0              NaN              NaN
# 25       298       152         0              NaN              NaN
# 26         9         7         1              2.0              1.0
# 27        11        23         0              NaN              NaN
# 28        23        11         0              2.0              2.0
# 29       163        93         2              NaN              NaN
# 30       161       112         1              1.0              0.0
# 31        52        46         0              3.0              2.0
# 32        34        50         0              1.0              0.0
# 33        48        34         0              NaN              NaN
# 34        98        90         2              NaN              NaN
#
#     playoffs l plyf  w/ team g plyf  w/ team w plyf  w/ team l plyf  \
# 0               NaN             1.0             0.0             1.0
# 1               NaN             NaN             NaN             NaN
# 2               1.0            20.0            11.0             9.0
# 3               1.0             9.0             4.0             5.0
# 4               NaN             NaN             NaN             NaN
# 5               NaN             NaN             NaN             NaN
# 6               NaN             NaN             NaN             NaN
# 7               1.0             7.0             5.0             2.0
# 8               NaN             2.0             1.0             1.0
# 9               1.0             3.0             1.0             2.0
# 10              NaN             NaN             NaN             NaN
# 11              NaN             NaN             NaN             NaN
# 12              NaN             NaN             NaN             NaN
# 13              NaN             5.0             2.0             3.0
# 14              NaN             NaN             NaN             NaN
# 15              NaN             3.0             1.0             2.0
# 16              NaN             NaN             NaN             NaN
# 17              1.0             2.0             1.0             1.0
# 18              0.0            18.0            11.0             7.0
# 19              1.0             1.0             0.0             1.0
# 20              NaN            10.0             7.0             3.0
# 21              NaN             NaN             NaN             NaN
# 22              1.0             1.0             0.0             1.0
# 23              1.0             1.0             0.0             1.0
# 24              NaN             NaN             NaN             NaN
# 25              NaN            42.0            30.0            12.0
# 26              1.0             2.0             1.0             1.0
# 27              NaN             NaN             NaN             NaN
# 28              0.0             3.0             2.0             1.0
# 29              NaN            17.0             8.0             9.0
# 30              1.0            19.0            10.0             9.0
# 31              1.0             9.0             6.0             3.0
# 32              1.0             1.0             0.0             1.0
# 33              NaN             5.0             2.0             3.0
# 34              NaN             1.0             0.0             1.0
#
#     career g plyf  career w plyf  career l plyf                       remark
# 0             1.0            0.0            1.0                          NaN
# 1             NaN            NaN            NaN                          NaN
# 2            20.0           11.0            9.0                          NaN
# 3             9.0            4.0            5.0                          NaN
# 4             NaN            NaN            NaN   Interim coach after week 5
# 5             NaN            NaN            NaN           Fired after week 5
# 6             NaN            NaN            NaN                          NaN
# 7             7.0            5.0            2.0                          NaN
# 8             2.0            1.0            1.0                          NaN
# 9            21.0           11.0           10.0                          NaN
# 10            NaN            NaN            NaN          Fired after week 16
# 11            NaN            NaN            NaN  Interim coach after week 16
# 12            NaN            NaN            NaN                          NaN
# 13            5.0            2.0            3.0                          NaN
# 14            6.0            3.0            3.0                          NaN
# 15            3.0            1.0            2.0           Fired after week 9
# 16            NaN            NaN            NaN   Interim coach after week 9
# 17            8.0            5.0            3.0                          NaN
# 18           37.0           21.0           16.0                          NaN
# 19            1.0            0.0            1.0                          NaN
# 20           10.0            7.0            3.0                          NaN
# 21            0.0            0.0            0.0                          NaN
# 22            1.0            0.0            1.0                          NaN
# 23            1.0            0.0            1.0                          NaN
# 24            0.0            0.0            0.0                          NaN
# 25           44.0           31.0           13.0                          NaN
# 26            2.0            1.0            1.0                          NaN
# 27            NaN            NaN            NaN                          NaN
# 28            3.0            2.0            1.0                          NaN
# 29           17.0            8.0            9.0                          NaN
# 30           22.0           11.0           11.0                          NaN
# 31            9.0            6.0            3.0                          NaN
# 32            1.0            0.0            1.0                          NaN
# 33            5.0            2.0            3.0                          NaN
# 34            8.0            3.0            5.0                          NaN

# %%
db_server='pymysql'
user='root'
db_port = '3306'
password = 'rootroot'
ip = 'localhost'
db_name = 'nflcopy'
engine = sqlalchemy.create_engine(f'mysql+{db_server}://{user}:{password}@{ip}:{db_port}/{db_name}?charset=utf8')
robo(url).to_sql(name_table, engine, index=False, if_exists='replace')
# Out:
# 35
