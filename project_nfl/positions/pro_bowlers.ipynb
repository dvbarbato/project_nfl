# %%
import pandas as pd
import numpy as np
import requests, time
from bs4 import BeautifulSoup
import sqlalchemy

pd.set_option('display.max_columns', None)

# %%
name_table = 'probowlers'

# %%
url = 'http://pfref.com/pi/share/mck1F'

# %%
def read_html(url):
    pd.read_html(url)
   
    return pd.read_html(url)

# %%
def convert_df(lista):
    lista[0]
    
    return lista[0]

# %%
def rm_unnamed_col(dado):
    dt = dado.rename(columns={'Yds.1':'Yds_Rush',
                              'Yds.2': 'Yds_receiving',
                              'Att.1':'Att_Rush',
                              'Int.1':'Int_Pass_def',
                              'TD.1':'TD_Rush',
                              'TD.2':'tD_receiving',
                              'All-pro teams': 'All_Pro_teams'})
    return dt

# %%
def add_col_characters(dataframe):
    dataframe.loc[:,'indicates_player_did_not_play'] = dataframe['Player'].str.contains('%', regex=False)
    dataframe.loc[:,'indicates_player_was_a_replacement selection'] = dataframe['Player'].str.contains('+', regex=False)
   
    return dataframe

# %%
def clean_col_player(dataframe):
    dataframe['Player'] = dataframe['Player'].str.replace('%','')
    dataframe['Player'] = dataframe['Player'].str.replace('+','')
    
    return dataframe

# %%
def limpar_todas_coluna(dataframe):
    dataframe.columns = [(c.lower().strip()) for c in dataframe.columns]
    
    return dataframe.columns

# %%
def robo(url):
    lista = read_html(url)
    converter_em_dataframe = convert_df(lista)
    tirar_nomes_coluna= rm_unnamed_col(converter_em_dataframe)
    adicionar_colunas_novas = add_col_characters(tirar_nomes_coluna)
    limpar_coluna_player = clean_col_player(adicionar_colunas_novas)
    dataframe_final = limpar_todas_coluna(limpar_coluna_player)
    
    
    
    return tirar_nomes_coluna

# %%
robo(url)
# Out:
# C:\Users\mateu\AppData\Local\Temp\ipykernel_11736\3552483734.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['Player'] = dataframe['Player'].str.replace('+','')
#      pos           player conf   tm  age   yrs   g  gs  cmp  att   yds  td  \
# 0     QB  Patrick Mahomes  AFC  KAN   27     5  17  17  435  648  5250  41
# 1     QB      Jalen Hurts  NFC  PHI   24     2  15  15  306  460  3701  22
# 2     QB       Joe Burrow  AFC  CIN   26     2  16  16  414  606  4475  35
# 3     QB       Josh Allen  AFC  BUF   26     4  16  16  359  567  4283  35
# 4     QB       Jared Goff  NFC  DET   28     6  17  17  382  587  4438  29
# ..   ...              ...  ...  ...  ...   ...  ..  ..  ...  ...   ...  ..
# 106  RET  KaVontae Turpin  NFC  DAL   26  Rook  17   0    0    0     0   0
# 107  RET      Jamal Agnew  NFC  JAX   27     5  15   0    0    0     0   0
# 108  RET   Devin Duvernay  NFC  BAL   25     2  14  13    0    0     0   0
# 109   ST    Jeremy Reaves  NFC  WAS   26     4  17   3    0    0     0   0
# 110   ST    Justin Hardee  NFC  NYJ   28     5  17   0    0    0     0   0
#
#      int  att_rush  yds_rush  td_rush  rec  yds_receiving  td_receiving  solo  \
# 0     12        61       358        4    1              6             0     1
# 1      6       165       760       13    0              0             0     2
# 2     12        75       257        5    0              0             0     0
# 3     14       124       762        7    0              0             0     3
# 4      7        29        73        0    1              5             0     2
# ..   ...       ...       ...      ...  ...            ...           ...   ...
# 106    0         3        17        0    1              9             0     1
# 107    0        12        86        0   23            187             3     1
# 108    0        12        84        1   37            407             3     0
# 109    0         0         0        0    0              0             0    20
# 110    0         0         0        0    0              0             0    10
#
#       sk  int_pass_def                                      all_pro_teams  \
# 0    0.0             0  FW: 1st Tm All-Conf., AP: 1st Tm, FW: 1st Tm, ...
# 1    0.0             0                   FW: 1st Tm All-Conf., AP: 2nd Tm
# 2    0.0             0                                        PFF: 2nd Tm
# 3    0.0             0                                                NaN
# 4    0.0             0                                                NaN
# ..   ...           ...                                                ...
# 106  0.0             0                                                NaN
# 107  0.0             0                                                NaN
# 108  0.0             0                                                NaN
# 109  0.0             0  FW: 1st Tm All-Conf., AP: 1st Tm, FW: 1st Tm, ...
# 110  0.0             0                               FW: 1st Tm All-Conf.
#
#      indicates_player_did_not_play  \
# 0                             True
# 1                             True
# 2                             True
# 3                             True
# 4                            False
# ..                             ...
# 106                          False
# 107                          False
# 108                           True
# 109                          False
# 110                          False
#
#      indicates_player_was_a_replacement selection
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                            True
# ..                                            ...
# 106                                         False
# 107                                          True
# 108                                         False
# 109                                         False
# 110                                         False
#
# [111 rows x 25 columns]

# %%
db_server='pymysql'
user='root'
db_port = '3306'
password = ''
ip = 'localhost'
db_name = 'nflcopy'
engine = sqlalchemy.create_engine(f'mysql+{db_server}://{user}:{password}@{ip}:{db_port}/{db_name}?charset=utf8')
robo(url).to_sql(name_table, engine, index=False, if_exists='replace')
# Out:
# C:\Users\mateu\AppData\Local\Temp\ipykernel_11736\3552483734.py:3: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['Player'] = dataframe['Player'].str.replace('+','')
# 111
