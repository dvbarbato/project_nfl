# %%
import pandas as pd
import numpy as np
import requests, time
from bs4 import BeautifulSoup
import sqlalchemy

pd.set_option('display.max_columns', None)

# %%
name_table = 'kicking'

# %%
url = 'http://pfref.com/pi/share/MERa7'

# %%
def read_html(url):
    pd.read_html(url)
   
    return pd.read_html(url)


def convert_df(lista):
    lista[0]
    
    return lista[0]


def rm_unnamed_col(dado):
    dt = dado.rename(columns={'Unnamed: 0_level_0':'',
                        'Unnamed: 1_level_0': '', 
                        'Unnamed: 2_level_0': '',
                        'Unnamed: 3_level_0': '',
                        'Unnamed: 4_level_0': '',
                        'Unnamed: 23_level_0': '',
                        'Unnamed: 17_level_0': ''
                             })
    return dt

def add_col_characters(dataframe):
    dataframe.loc[:,'All-Pro'] = dataframe['','Player'].str.contains('+', regex=False)
    dataframe.loc[:,'Selected_Pro_Bowl'] = dataframe['','Player'].str.contains('*', regex=False)
   
    return dataframe

def clean_col_player(dataframe):
    dataframe['','Player'] = dataframe['', 'Player'].str.replace('*','')
    dataframe['','Player'] = dataframe['', 'Player'].str.replace('+','')
    
    return dataframe

def limpar_todas_coluna(dataframe):
    dataframe.columns = [(c.lower().strip() + ' '+ d.lower().strip()).strip() for c,d in dataframe.columns]
    
    return dataframe.columns

# %%
def robo(url):
    lista = read_html(url)
    converter_em_dataframe = convert_df(lista)
    tirar_nomes_coluna= rm_unnamed_col(converter_em_dataframe)
    adicionar_colunas_novas = add_col_characters(tirar_nomes_coluna)
    limpar_coluna_player = clean_col_player(adicionar_colunas_novas)
    dataframe_final = limpar_todas_coluna(limpar_coluna_player)
    
    
    
    
    
    return tirar_nomes_coluna

# %%
robo(url)
# Out:
# C:\Users\mateu\AppData\Local\Temp\ipykernel_12852\306468359.py:31: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['','Player'] = dataframe['', 'Player'].str.replace('*','')
# C:\Users\mateu\AppData\Local\Temp\ipykernel_12852\306468359.py:32: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['','Player'] = dataframe['', 'Player'].str.replace('+','')
#     rk           player   tm  age pos  games g  games gs  0-19 fga  0-19 fgm  \
# 0    1    Justin Tucker  BAL   33   K       17         0       NaN       NaN
# 1    2      Ryan Succop  TAM   36   K       17         0       NaN       NaN
# 2    3      Jason Myers  SEA   31   K       17         0       NaN       NaN
# 3    4   Daniel Carlson  LVR   27   K       17         0       NaN       NaN
# 4    5        Nick Folk  NWE   38   K       17         0       1.0       1.0
# ..  ..              ...  ...  ...  ..      ...       ...       ...       ...
# 59  60    Johnny Hekker  CAR   32   P       17         0       NaN       NaN
# 60  61       Sam Martin  BUF   32   P       16         0       NaN       NaN
# 61  62  Thomas Morstead  MIA   36   P       17         0       NaN       NaN
# 62  63     Arryn Siposs  PHI   30   P       13         0       NaN       NaN
# 63  64        Tress Way  WAS   32   P       17         0       NaN       NaN
#
#     20-29 fga  20-29 fgm  30-39 fga  30-39 fgm  40-49 fga  40-49 fgm  50+ fga  \
# 0        13.0       13.0       11.0       11.0        5.0        4.0     14.0
# 1        11.0       10.0        8.0        7.0       12.0       12.0      7.0
# 2         9.0        9.0       16.0       15.0        6.0        4.0      6.0
# 3         9.0        9.0       11.0       11.0        4.0        3.0     13.0
# 4         9.0        9.0        8.0        8.0       14.0       10.0      5.0
# ..        ...        ...        ...        ...        ...        ...      ...
# 59        NaN        NaN        NaN        NaN        NaN        NaN      NaN
# 60        NaN        NaN        NaN        NaN        NaN        NaN      NaN
# 61        NaN        NaN        NaN        NaN        NaN        NaN      NaN
# 62        NaN        NaN        NaN        NaN        NaN        NaN      NaN
# 63        NaN        NaN        NaN        NaN        NaN        NaN      NaN
#
#     50+ fgm  scoring fga  scoring fgm  scoring lng scoring fg%  scoring xpa  \
# 0       9.0         43.0         37.0         58.0       86.0%         32.0
# 1       2.0         38.0         31.0         54.0       81.6%         25.0
# 2       6.0         37.0         34.0         56.0       91.9%         42.0
# 3      11.0         37.0         34.0         57.0       91.9%         36.0
# 4       4.0         37.0         32.0         54.0       86.5%         35.0
# ..      ...          ...          ...          ...         ...          ...
# 59      NaN          NaN          NaN          NaN         NaN          NaN
# 60      NaN          NaN          NaN          NaN         NaN          NaN
# 61      NaN          NaN          NaN          NaN         NaN          NaN
# 62      NaN          NaN          NaN          NaN         NaN          NaN
# 63      NaN          NaN          NaN          NaN         NaN          NaN
#
#     scoring xpm scoring xp%  kickoffs ko  kickoffs koyds  kickoffs tb  \
# 0          31.0       96.9%         86.0          5449.0         60.0
# 1          24.0       96.0%          NaN             NaN          NaN
# 2          41.0       97.6%         93.0          5839.0         54.0
# 3          35.0       97.2%         90.0          5546.0         57.0
# 4          32.0       91.4%         35.0          2066.0          3.0
# ..          ...         ...          ...             ...          ...
# 59          NaN         NaN          1.0             8.0          NaN
# 60          NaN         NaN          1.0            63.0          NaN
# 61          NaN         NaN          1.0            73.0          NaN
# 62          NaN         NaN          1.0            70.0          NaN
# 63          NaN         NaN          1.0            63.0          NaN
#
#    kickoffs tb%  kickoffs koavg  all-pro  selected_pro_bowl
# 0         69.8%            63.4    False               True
# 1           NaN             NaN    False              False
# 2         58.1%            62.8    False               True
# 3         63.3%            61.6     True              False
# 4          8.6%            59.0    False              False
# ..          ...             ...      ...                ...
# 59          NaN             8.0    False              False
# 60          NaN            63.0    False              False
# 61          NaN            73.0    False              False
# 62          NaN            70.0    False              False
# 63          NaN            63.0    False               True
#
# [64 rows x 31 columns]

# %%
db_server='pymysql'
user='root'
db_port = '3306'
password = 'rootroot'
ip = 'localhost'
db_name = 'nflcopy'
engine = sqlalchemy.create_engine(f'mysql+{db_server}://{user}:{password}@{ip}:{db_port}/{db_name}?charset=utf8')
robo(url).to_sql(name_table, engine, index=False, if_exists='replace')
# Out:
# C:\Users\mateu\AppData\Local\Temp\ipykernel_12852\306468359.py:31: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['','Player'] = dataframe['', 'Player'].str.replace('*','')
# C:\Users\mateu\AppData\Local\Temp\ipykernel_12852\306468359.py:32: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['','Player'] = dataframe['', 'Player'].str.replace('+','')
# 64
