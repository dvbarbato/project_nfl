# %%
import pandas as pd
import numpy as np
import requests, time
from bs4 import BeautifulSoup
import sqlalchemy

pd.set_option('display.max_columns', None)

# %%
name_table = 'puting'

# %%
url = 'http://pfref.com/pi/share/BKsoQ'

# %%
def read_html(url):
    pd.read_html(url)
   
    return pd.read_html(url)


def convert_df(lista):
    lista[0]
    
    return lista[0]


def rm_unnamed_col(dado):
    dt = dado.rename(columns={'Unnamed: 0_level_0':'',
                        'Unnamed: 1_level_0': '', 
                        'Unnamed: 2_level_0': '',
                        'Unnamed: 3_level_0': '',
                        'Unnamed: 4_level_0': ''
                             })
    return dt

def add_col_characters(dataframe):
    dataframe.loc[:,'All-Pro'] = dataframe['','Player'].str.contains('+', regex=False)
    dataframe.loc[:,'Selected_Pro_Bowl'] = dataframe['','Player'].str.contains('*', regex=False)
   
    return dataframe

def clean_col_player(dataframe):
    dataframe['','Player'] = dataframe['', 'Player'].str.replace('*','')
    dataframe['','Player'] = dataframe['', 'Player'].str.replace('+','')
    
    return dataframe

def limpar_todas_coluna(dataframe):
    dataframe.columns = [(c.lower().strip() + ' '+ d.lower().strip()).strip() for c,d in dataframe.columns]
    
    return dataframe.columns

# %%
def robo(url):
    lista = read_html(url)
    converter_em_dataframe = convert_df(lista)
    tirar_nomes_coluna= rm_unnamed_col(converter_em_dataframe)
    adicionar_colunas_novas = add_col_characters(tirar_nomes_coluna)
    limpar_coluna_player = clean_col_player(adicionar_colunas_novas)
    dataframe_final = limpar_todas_coluna(limpar_coluna_player)
    
    
    
    
    
    return tirar_nomes_coluna

# %%
robo(url)
# Out:
# C:\Users\mateu\AppData\Local\Temp\ipykernel_20692\753688841.py:29: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['','Player'] = dataframe['', 'Player'].str.replace('*','')
# C:\Users\mateu\AppData\Local\Temp\ipykernel_20692\753688841.py:30: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['','Player'] = dataframe['', 'Player'].str.replace('+','')
#     rk               player   tm  age pos  games g  games gs  punting pnt  \
# 0    1      Corliss Waitman  DEN   27   P       17         0           96
# 1    2      Ryan Stonehouse  TEN   23   P       17         0           90
# 2    3     Cameron Johnston  HOU   30   P       17         0           88
# 3    4          Braden Mann  NYJ   25   P       17         0           83
# 4    5            Tress Way  WAS   32   P       17         0           83
# 5    6        Johnny Hekker  CAR   32   P       17         0           81
# 6    7         Jake Camarda  TAM   23   P       17         0           79
# 7    8       Blake Gillikin  NOR   24   P       17         0           77
# 8    9         Jamie Gillan  NYG   25   P       17         0           74
# 9   10             JK Scott  LAC   27   P       17         0           73
# 10  11          Ryan Wright  MIN   22   P       17         0           73
# 11  12          Riley Dixon  LAR   29   P       17         0           71
# 12  13           Matt Haack  IND   28   P       17         0           70
# 13  14  Pressley Harvin III  PIT   24   P       17         0           69
# 14  15          Bryan Anger  DAL   34   P       17         0           68
# 0            59           6        6.3%            30         31.3%
# 1            74           9       10.0%            30         33.3%
# 2            67           4        4.5%            37         42.0%
# 3            72           8        9.6%            27         32.5%
# 4            68           5        6.0%            37         44.6%
# 5            68           6        7.4%            39         48.1%
# 6            74          10       12.7%            22         27.8%
# 7            68           7        9.1%            32         41.6%
# 8            69           9       12.2%            26         35.1%
# 9            60           5        6.8%            28         38.4%
# 10           73           1        1.4%            32         43.8%
# 11           67           4        5.6%            19         26.8%
# 12           70           3        4.3%            28         40.0%
# 13           69           5        7.2%            20         29.0%
# 14           83           6        8.8%            27         39.7%
# 15           65           4        6.0%            18         26.9%
# 16           68           3        4.5%            22         33.3%
# 17           63           3        4.5%            20         30.3%
# 18           73           2        3.2%            23         37.1%
# 19           76           7       11.5%            23         37.7%
# 20           66           2        3.3%            28         45.9%
# 21           74           5        8.2%            32         52.5%
# 22           67           1        1.7%            26         44.1%
# 23           70           6       10.3%            24         41.4%
# 24           69           7       12.3%            26         45.6%
# 25           76           4        7.5%            22         41.5%
# 26           66           3        5.8%            14         26.9%
# 27           72           1        1.9%            24         46.2%
# 28           67           5       11.1%            16         35.6%
# 29           59           3        6.8%            16         36.4%
# 30           58           5       11.9%            10         23.8%
# 31           62           5       13.5%            12         32.4%
# 32           63           1        3.2%             9         29.0%
# 33           65           2        7.1%            13         46.4%
# 34           53           0        0.0%             1         10.0%
# 35           35           0        0.0%             0          0.0%
#
#     punting blck  all-pro  selected_pro_bowl
# 0              0    False              False
# 1              0    False              False
# 2              0    False              False
# 3              0    False              False
# 4              0    False               True
# 5              0    False              False
# 6              0    False              False
# 7              0    False              False
# 8              1    False              False
# 9              0    False              False
# 10             1    False              False
# 11             2    False              False
# 12             1    False              False
# 13             0    False              False
# 14             0    False              False
# 15             1    False              False
# 16             0    False              False
# 17             1    False              False
# 18             0    False              False
# 19             0    False              False
# 20             0    False              False
# 21             0    False              False
# 22             0    False               True
# 23             0    False              False
# 24             0    False              False
# 25             0     True               True
# 26             0    False              False
# 27             2    False              False
# 28             1    False              False
# 29             1    False              False
# 30             1    False              False
# 31             0    False              False
# 32             0    False              False
# 33             0    False              False
# 34             0    False              False
# 35             0    False              False

# %%
db_server='pymysql'
user='root'
db_port = '3306'
password = ''
ip = 'localhost'
db_name = 'nflcopy'
engine = sqlalchemy.create_engine(f'mysql+{db_server}://{user}:{password}@{ip}:{db_port}/{db_name}?charset=utf8')
robo(url).to_sql(name_table, engine, index=False, if_exists='replace')
# Out:
# C:\Users\mateu\AppData\Local\Temp\ipykernel_20692\753688841.py:29: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['','Player'] = dataframe['', 'Player'].str.replace('*','')
# C:\Users\mateu\AppData\Local\Temp\ipykernel_20692\753688841.py:30: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   dataframe['','Player'] = dataframe['', 'Player'].str.replace('+','')
# 36
