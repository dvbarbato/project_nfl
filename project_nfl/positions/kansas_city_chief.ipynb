# %%
import pandas as pd
import numpy as np
import requests, time
from bs4 import BeautifulSoup
import sqlalchemy

pd.set_option('display.max_columns', None)

# %%
name_table = 'kansas_city_chief'

# %%
url = 'http://pfref.com/pi/share/gnMow'

# %%
def read_html(url):
    pd.read_html(url)
   
    return pd.read_html(url)

# %%
def convert_df(lista):
    lista[0]
    
    return lista[0]

# %%
# def rm_unnamed_col(dado):
#     dt = dado.rename(columns={'Yds.1':'Yds_sk'})
#     return dt

# %%
# def add_col_characters(dataframe):
#     dataframe.loc[:,'All-Pro'] = dataframe['Player'].str.contains('+', regex=False)
#     dataframe.loc[:,'Selected_Pro_Bowl'] = dataframe['Player'].str.contains('*', regex=False)
   
#     return dataframe

# %%
# def clean_col_player(dataframe):
#     dataframe['Player'] = dataframe['Player'].str.replace('*','')
#     dataframe['Player'] = dataframe['Player'].str.replace('+','')
    
#     return dataframe

# %%
def limpar_todas_coluna(dataframe):
    dataframe.columns = [(c.lower().strip()) for c in dataframe.columns]
    
    return dataframe.columns

# %%
def robo(url):
    lista = read_html(url)
    converter_em_dataframe = convert_df(lista)
    #tirar_nomes_coluna= rm_unnamed_col(converter_em_dataframe)
    #adicionar_colunas_novas = add_col_characters(tirar_nomes_coluna)
    #limpar_coluna_player = clean_col_player(adicionar_colunas_novas)
    dataframe_final = limpar_todas_coluna(converter_em_dataframe)
    
    
    
    return converter_em_dataframe

# %%
robo(url)
# Out:
#     no.                    player  age pos   g  gs   wt    ht  \
# 0    73           Nick Allegretti   26   G  17   3  315   6-4
# 1    81                Blake Bell   31  TE   3   1  260   6-6
# 2    32               Nick Bolton   22  LB  17  17  237   6-0
# 3    57         Orlando Brown Jr.   26   T  17  17  363   6-8
# 4    12            Shane Buechele   24  QB   0   0  207   6-1
# 5    45            Michael Burton   30  FB  17   0  243   6-0
# 6    26                 Deon Bush   29  DB  16   0  187   6-0
# 7     7           Harrison Butker   27   K  13   0  196   6-4
# 8    54                Leo Chenal   22  LB  17   8  255   6-2
# 9    55               Frank Clark   29  DE  15  15  261   6-3
# 10   43             Jack Cochrane   23  LB  15   0  230   6-3
# 11    6                Bryan Cook   23   S  16   1  210   6-1
# 12   51             Michael Danna   25  DE  13   0  255   6-2
# 13    8             Carlos Dunlap   33  DE  17   2  285   6-6
# 14   25     Clyde Edwards-Helaire   23  RB  10   6  209   5-8
# 15   88              Jody Fortson   27  TE  13   1  230   6-6
# 16   50            Willie Gay Jr.   24  LB  13  13  235   6-2
# 17   83                 Noah Gray   23  TE  17   8  240   6-4
# 18   47             Darius Harris   26  LB  17   4  238   6-2
# 19    4                Chad Henne   37  QB   3   0  215   6-3
# 20   70             Malik Herring   25  DE   7   0  280   6-3
# 21   52            Creed Humphrey   23   C  17  17  309   6-5
# 22   13            Nazeeh Johnson   24   S  11   0  189   6-2
# 23   95               Chris Jones   28  DT  17  17  298   6-6
# 24    2           Ronald Jones II   25  RB   6   0  208  5-11
# 25   59            Joshua Kaindoh   24  DE   0   0  262   6-5
# 26   56      George Karlaftis III   21  DE  17  17  275   6-4
# 27   87              Travis Kelce   33  TE  17  17  256   6-5
# 28   75            Darian Kinnard   23   T   1   0  345   6-5
# 29   15           Patrick Mahomes   27  QB  17  17  227   6-3
# 30   21            Trent McDuffie   22  CB  11  11  195  5-11
# 31    1           Jerick McKinnon   30  RB  17   0  201   5-9
# 32   24                Skyy Moore   22  WR  16   3  195  5-10
# 33   67               Lucas Niang   24  OL   7   0  339   6-6
# 34   91             Derrick Nnadi   26  DT  17  17  317   6-1
# 35   10             Isiah Pacheco   22  RB  17  11  215  5-11
# 36   20               Justin Reid   25   S  17  17  203   6-1
# 37   99           Khalen Saunders   26  DT  16   0  324   6-0
# 38   65                Trey Smith   23  OL  16  16  329   6-5
# 39    9       JuJu Smith-Schuster   26  WR  16  14  215   6-1
# 40   38            L'Jarius Sneed   25  CB  17  17  189   6-0
# 41   22            Juan Thornhill   27   S  16  16  203   6-0
# 42   62                Joe Thuney   30  OL  15  15  304   6-5
# 43   19            Kadarius Toney   23  WR   7   3  193   6-0
# 44    5            Tommy Townsend   26   P  17   0  194   6-1
# 45   11  Marquez Valdes-Scantling   28  WR  17  11  206   6-4
# 46   70       Prince Tega Wanogho   25   T  17   0  308   6-5
# 47   35             Jaylen Watson   24  CB  16   6  204   6-3
# 48   84             Justin Watson   26  WR  17   5  215   6-3
# 49   66          Brandon Williams   33  DT   5   0  336   6-1
# 50   23           Joshua Williams   23  DB  17   4  197   6-3
# 51   41          James Winchester   33  LS  17   0  242   6-3
# 52   77              Andrew Wylie   28   G  17  17  310   6-6
# 53   98    Tershawn Wharton (IRD)   24  DT   5   0  278   6-4
# 54   46        Jordan Franks (IR)   26  TE   0   0  240   6-4
# 55   17       Mecole Hardman (IR)   24  WR   8   5  187  5-10
# 56   14       Cornell Powell (IR)   25  WR   3   0  210   6-0
# 57    8          Justyn Ross (IR)   23  WR   0   0  205   NaN
#
#                         college/univ   birthdate   yrs    av  \
# 0                           Illinois   4/21/1996     3   3.0
# 1                           Oklahoma    8/7/1991     7   0.0
# 2                           Missouri   3/10/2000     1   7.0
# 3                           Oklahoma    5/2/1996     4  13.0
# 4                          Texas,SMU    1/8/1998  Rook   NaN
# 5                            Rutgers    2/1/1992     7   0.0
# 6                         Miami (FL)   8/14/1993     6   1.0
# 7                       Georgia Tech   7/14/1995     5   1.0
# 8                          Wisconsin  10/26/2000  Rook   4.0
# 9                           Michigan   6/14/1993     7   6.0
# 10                      South Dakota    2/9/1999  Rook   1.0
# 11                 Howard,Cincinnati    9/7/1999  Rook   1.0
# 9        Seattle Seahawks / 2nd / 63rd pick / 2015
# 10                                             NaN
# 11     Kansas City Chiefs / 2nd / 62nd pick / 2022
# 12    Kansas City Chiefs / 5th / 177th pick / 2020
# 13     Cincinnati Bengals / 2nd / 54th pick / 2010
# 14     Kansas City Chiefs / 1st / 32nd pick / 2020
# 15                                             NaN
# 16     Kansas City Chiefs / 2nd / 63rd pick / 2020
# 17    Kansas City Chiefs / 5th / 162nd pick / 2021
# 18                                             NaN
# 19         Miami Dolphins / 2nd / 57th pick / 2008
# 20                                             NaN
# 21     Kansas City Chiefs / 2nd / 63rd pick / 2021
# 22    Kansas City Chiefs / 7th / 259th pick / 2022
# 23     Kansas City Chiefs / 2nd / 37th pick / 2016
# 24   Tampa Bay Buccaneers / 2nd / 38th pick / 2018
# 25    Kansas City Chiefs / 4th / 144th pick / 2021
# 26     Kansas City Chiefs / 1st / 30th pick / 2022
# 27     Kansas City Chiefs / 3rd / 63rd pick / 2013
# 28    Kansas City Chiefs / 5th / 145th pick / 2022
# 29     Kansas City Chiefs / 1st / 10th pick / 2017
# 30     Kansas City Chiefs / 1st / 21st pick / 2022
# 31      Minnesota Vikings / 3rd / 96th pick / 2014
# 32     Kansas City Chiefs / 2nd / 54th pick / 2022
# 33     Kansas City Chiefs / 3rd / 96th pick / 2020
# 34     Kansas City Chiefs / 3rd / 75th pick / 2018
# 35    Kansas City Chiefs / 7th / 251st pick / 2022
# 36         Houston Texans / 3rd / 68th pick / 2018
# 37     Kansas City Chiefs / 3rd / 84th pick / 2019
# 38    Kansas City Chiefs / 6th / 226th pick / 2021
# 39    Pittsburgh Steelers / 2nd / 62nd pick / 2017
# 40    Kansas City Chiefs / 4th / 138th pick / 2020
# 41     Kansas City Chiefs / 2nd / 63rd pick / 2019
# 42   New England Patriots / 3rd / 78th pick / 2016
# 43        New York Giants / 1st / 20th pick / 2021
# 44                                             NaN
# 45     Green Bay Packers / 5th / 174th pick / 2018
# 46   Philadelphia Eagles / 6th / 210th pick / 2020
# 47    Kansas City Chiefs / 7th / 243rd pick / 2022
# 48  Tampa Bay Buccaneers / 5th / 144th pick / 2018
# 49       Baltimore Ravens / 3rd / 94th pick / 2013
# 50    Kansas City Chiefs / 4th / 135th pick / 2022
# 51                                             NaN
# 52                                             NaN
# 53                                             NaN
# 54                                             NaN
# 55     Kansas City Chiefs / 2nd / 56th pick / 2019
# 56    Kansas City Chiefs / 5th / 181st pick / 2021
# 57                                             NaN

# %%
db_server='pymysql'
user='root'
db_port = '3306'
password = 'rootroot'
ip = 'localhost'
db_name = 'nflcopy'
engine = sqlalchemy.create_engine(f'mysql+{db_server}://{user}:{password}@{ip}:{db_port}/{db_name}?charset=utf8')
robo(url).to_sql(name_table, engine, index=False, if_exists='replace')
# Out:
# 58
