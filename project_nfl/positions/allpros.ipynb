# %%
import pandas as pd
import numpy as np
import requests, time
from bs4 import BeautifulSoup
import sqlalchemy

pd.set_option('display.max_columns', None)

# %%
name_table = 'allpros'

# %%
url = 'http://pfref.com/pi/share/nkXqw'

# %%
def read_html(url):
    pd.read_html(url)
   
    return pd.read_html(url)

# %%
def convert_df(lista):
    lista[0]
    
    return lista[0]

# %%
def rm_unnamed_col(dado):
    dt = dado.rename(columns={'Yds.1':'Yds_Rush',
                              'Yds.2': 'Yds_receiving',
                              'Att.1':'Att_Rush',
                              'Int.1':'Int_Pass_def',
                              'TD.1':'TD_Rush',
                              'TD.2':'tD_receiving',
                              'All-pro teams': 'All_Pros_teams'})
    return dt

# %%
# def add_col_characters(dataframe):
#     dataframe.loc[:,'All-Pro'] = dataframe['Player'].str.contains('+', regex=False)
#     dataframe.loc[:,'Selected_Pro_Bowl'] = dataframe['Player'].str.contains('*', regex=False)
   
#     return dataframe

# %%
# def clean_col_player(dataframe):
#     dataframe['Player'] = dataframe['Player'].str.replace('*','')
#     dataframe['Player'] = dataframe['Player'].str.replace('+','')
    
#     return dataframe

# %%
def limpar_todas_coluna(dataframe):
    dataframe.columns = [(c.lower().strip()) for c in dataframe.columns]
    
    return dataframe.columns

# %%
def robo(url):
    lista = read_html(url)
    converter_em_dataframe = convert_df(lista)
    tirar_nomes_coluna= rm_unnamed_col(converter_em_dataframe)
    #adicionar_colunas_novas = add_col_characters(tirar_nomes_coluna)
    #limpar_coluna_player = clean_col_player(adicionar_colunas_novas)
    dataframe_final = limpar_todas_coluna(tirar_nomes_coluna)
    
    
    
    return tirar_nomes_coluna

# %%
robo(url)
# Out:
#        pos           player   tm  age yrs   g  gs  cmp  att   yds  td  int  \
# 0       QB  Patrick Mahomes  KAN   27   5  17  17  435  648  5250  41   12
# 1       QB      Jalen Hurts  PHI   24   2  15  15  306  460  3701  22    6
# 2       QB       Joe Burrow  CIN   26   2  16  16  414  606  4475  35   12
# 3       RB      Josh Jacobs  LVR   24   3  17  17    0    0     0   0    0
# 4       RB       Nick Chubb  CLE   27   4  17  17    0    0     0   0    0
# ..     ...              ...  ...  ...  ..  ..  ..  ...  ...   ...  ..  ...
# 82      KR     Nyheim Hines  2TM   26   4  16   5    0    0     0   0    0
# 83      ST    Jeremy Reaves  WAS   26   4  17   3    0    0     0   0    0
# 84      ST    Justin Hardee  NYJ   28   5  17   0    0    0     0   0    0
# 85      ST      George Odum  SFO   29   4  17   0    0    0     0   0    0
# 86  FLEX-D     Jalen Ramsey  LAR   28   6  17  17    0    0     0   0    0
#
#     att_rush  yds_rush  td_rush  rec  yds_receiving  td_receiving  solo   sk  \
# 0         61       358        4    1              6             0     1  0.0
# 1        165       760       13    0              0             0     2  0.0
# 2         75       257        5    0              0             0     0  0.0
# 3        340      1653       12   53            400             0     2  0.0
# 4        302      1525       12   27            239             1     0  0.0
# ..       ...       ...      ...  ...            ...           ...   ...  ...
# 82        24        33        1   30            241             1     2  0.0
# 83         0         0        0    0              0             0    20  0.0
# 84         0         0        0    0              0             0    10  0.0
# 85         0         0        0    0              0             0    16  0.0
# 86         0         0        0    0              0             0    64  2.0
#
#     int_pass_def                                     all_pros_teams
# 0              0  FW: 1st Tm All-Conf., AP: 1st Tm, FW: 1st Tm, ...
# 1              0                   FW: 1st Tm All-Conf., AP: 2nd Tm
# 2              0                                        PFF: 2nd Tm
# 3              0  FW: 1st Tm All-Conf., AP: 1st Tm, FW: 1st Tm, ...
# 4              0  FW: 1st Tm All-Conf., AP: 2nd Tm, FW: 1st Tm, ...
# ..           ...                                                ...
# 82             0                               FW: 1st Tm All-Conf.
# 83             0  FW: 1st Tm All-Conf., AP: 1st Tm, FW: 1st Tm, ...
# 84             0                               FW: 1st Tm All-Conf.
# 85             1                            AP: 2nd Tm, PFF: 2nd Tm
# 86             4                                        PFF: 1st Tm
#
# [87 rows x 22 columns]

# %%
db_server='pymysql'
user='root'
db_port = '3306'
password = 'rootroot'
ip = 'localhost'
db_name = 'nflcopy'
engine = sqlalchemy.create_engine(f'mysql+{db_server}://{user}:{password}@{ip}:{db_port}/{db_name}?charset=utf8')
robo(url).to_sql(name_table, engine, index=False, if_exists='replace')
# Out:
# 87
